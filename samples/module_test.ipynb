# %%
require '../lib/imulvery'
# Out:
# true

# %%
bd = IMulvery::BlockDiagram.new
# Out:
# #<IMulvery::BlockDiagram:0x0000558c115ec2c8 @modules=[]>

# %%
bd.add_module(
  "test_module",
  {clk: 1, din: 32, valid: 1},
  {result: 32, enable: 1})
IRuby.display(bd.read, mime: "image/png")
# Out:
# "\x89PNG\r\n\u001A\n\u0000\u0000\u0000\rIHDR\u0000\u0000\u0001,\u0000\u0000\u0000\xC8\b\u0002\u0000\u0000\u0000ݽK\u0002\u0000\u0000\u0000\u0006bKGD\u0000\xFF\u0000\xFF\u0000\xFF\xA0\xBD\xA7\x93\u0000\u0000\u0011\x88IDATx\x9C\xED\xDDy@\xCC\xE9\u001F\a\xF0gjf\x9Af\xBAE\xBA\xB3I[j)!!\xC4:7\xAC\u0092#\xE7\xAEu\xED\xBA\xAD\xD0:\x96\\k\xD7.b\xD1b\xC5\xCA\xDA6\xAC\xDCd\xB3\x8EPD\xCAա\xC4t\x9Ft\xFD\xFE\xF8\xAEi~MM\xD3hzf\xA6\xF7믙\xEF\xCC|{\x9E\xAFy\xFB\u001E\xCF\xF7\xF3\f+==\x9D\u0000\u0000=\u001A\xB4\e\u0000\xD0\xDC!\x84\u0000\x94!\x84\u0000\x94!\x84\u0000\x94!\x84\u0000\x94!\x84\u0000\x94!\x84\u0000\x94!\x84\u0000\x94!\x84\u0000\x94\xB1i7\xA0~e\u0015\u001A\xC9B~F\u000E\xAF\xA8\x94]V\xC1\xA2\xDD\u001Ch\u00168\x9AU\u0002^\xB9\xA9a\xA9\xB5q1G\xB3R\xA1\u007F\x8B\xA5䷭\xA5g\xF3\xEE\xA5\xEA\xBF-\xC7\u001E\e\xE8\xE0\xB2+\x9D-\xF3̌J\u0015\xF7'\x94zO\xF8$S\xE7A\x9A.\xEDV@\xB3\xF6\xB6\\#\xE6\x99aIY\x81\xADI\xA1\x82\xFE\x84\xF2\xEEaҳyH (\x89\ai\xBA\xE9\xD9<\u0005\xAD\\ICXV\xA1q/U\x9Fv+\u0000\xAAť(\xEA
# ...
